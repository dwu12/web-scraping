# %%
from bs4 import BeautifulSoup, NavigableString, Tag
import pandas as pd
import os
import markdown

# %%
# Function to parse markdown file and convert to HTML
def parse_markdown_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        markdown_content = f.read()
    
    # Convert markdown to HTML
    html_content = markdown.markdown(markdown_content, extensions=['fenced_code', 'tables'])
    
    return html_content

# Example usage
file_path = './markdown_file/firecralwer_get-started-japan.md'
html_content = parse_markdown_file(file_path)

# %%
soup = BeautifulSoup(html_content, 'html.parser')
    
# Find all h2 headings
h2_headings = soup.find_all('h2')

# %%
soup
# Out:
# <p><a href="#content">Skip to main content</a> <a href="#search">Skip to search</a></p>
# <p>Powered by Zoomin Software. For more details please contact <a href="https://www.zoominsoftware.com">Zoomin</a></p>
# <p><a href="https://www.here.com/docs/search?personalize=true&amp;q=how%20do%20I%20get%20an%20api%20key%3F">Try using our new AI features to get answers to your questions. To ask AI a question, add a question mark (?) to the end of a search query. Click here to try it out.</a></p>
# <h2>HERE Maps API for JavaScript - Developer Guide</h2>
# <p>Filters</p>
# <h2>Filters</h2>
# <p>Clear All Filters</p>
# <h5>Product category</h5>
# <ul>
# <li>
# <p>Dynamic map content</p>
# </li>
# <li>
# <p>HERE Destination Weather API v3</p>
# </li>
# <li>
# <p>HERE Destination Weather API v1</p>
# </li>
# <li>
# <p>HERE Map Attributes API</p>
# </li>
# <li>
# <p>HERE EV Charge Points API</p>
# </li>
# <li>
# <p>HERE Fuel Prices API</p>
# </li>
# <li>
# <p>HERE On-Street Parking API</p>
# </li>
# <li>
# <p>HERE Off-Street Parking API</p>
# </li>
# <li>
# <p>Map data</p>
# </li>
# <li>
# <p>Introduction to Mapping Concepts</p>
# </li>
# <li>
# <p>HERE Map Layers</p>
# <ul>
# <li>
# <p>Administrative Regions</p>
# </li>
# <li>
# <p>Buildings</p>
# </li>
# <li>
# <p>Cartography</p>
# </li>
# <li>
# <p>Destination Signs</p>
# </li>
# <li>
# <p>Places</p>
# </li>
# <li>
# <p>Road Network</p>
# </li>
# <li>
# <p>Traffic Signs</p>
# </li>
# <li>HERE Indoor Map</li>
# </ul>
# </li>
# <li>
# <p>HERE Lanes</p>
# </li>
# <li>
# <p>HERE Lidar Data</p>
# </li>
# <li>
# <p>HERE Map Content</p>
# <ul>
# <li>HERE Map Content - Schema</li>
# <li>HERE Map Feedback API</li>
# </ul>
# </li>
# <li>
# <p>HERE Maps XML</p>
# </li>
# <li>
# <p>HERE Safety Cameras Feed API</p>
# </li>
# <li>
# <p>HERE Studio</p>
# </li>
# <li>
# <p>Embedded Editor</p>
# </li>
# <li>
# <p>Location services</p>
# </li>
# <li>
# <p>HERE Geocoding and Search</p>
# <ul>
# <li>
# <p>HERE Geocoding and Search API v7</p>
# </li>
# <li>
# <p>HERE Batch API v7</p>
# </li>
# <li>
# <p>HERE Geocoder API</p>
# </li>
# <li>
# <p>HERE Geocoder Autocomplete API</p>
# </li>
# <li>
# <p>HERE Batch Geocoder API</p>
# </li>
# <li>
# <p>HERE Places Search API</p>
# </li>
# <li>
# <p>HERE Map Rendering</p>
# </li>
# <li>
# <p>HERE Vector Tile API</p>
# </li>
# <li>
# <p>HERE Raster Tile API</p>
# </li>
# <li>
# <p>HERE Maps API for JavaScript</p>
# </li>
# <li>
# <p>HERE Map Tile V2</p>
# </li>
# <li>
# <p>HERE Map Image V1</p>
# </li>
# <li>
# <p>HERE Map Image V3</p>
# </li>
# <li>
# <p>HERE Positioning</p>
# </li>
# <li>
# <p>HERE Network Positioning API v2</p>
# </li>
# <li>
# <p>HERE HD GNSS and A-GNSS Positioning</p>
# </li>
# <li>
# <p>HERE HD GNSS Positioning API</p>
# </li>
# <li>
# <p>HERE Network Positioning API v1</p>
# </li>
# <li>
# <p>HERE Routing</p>
# </li>
# <li>
# <p>HERE Routing API V8</p>
# </li>
# <li>
# <p>HERE Isoline Routing API v8</p>
# </li>
# <li>
# <p>HERE Matrix Routing API v8</p>
# </li>
# <li>
# <p>HERE Route Matching API</p>
# </li>
# <li>
# <p>HERE Waypoints Sequence API v8</p>
# </li>
# <li>
# <p>HERE Geofencing API</p>
# </li>
# <li>
# <p>HERE Routing API v7</p>
# </li>
# <li>HERE Tour Planning API</li>
# </ul>
# </li>
# <li>
# <p>HERE Fleet Telematics API</p>
# </li>
# <li>
# <p>HERE Transit</p>
# <ul>
# <li>
# <p>HERE Public Transit API v8</p>
# </li>
# <li>
# <p>HERE Intermodal Routing API v8</p>
# </li>
# <li>
# <p>HERE Traffic</p>
# </li>
# <li>
# <p>HERE Traffic API v7</p>
# </li>
# <li>
# <p>HERE Traffic API v6</p>
# </li>
# <li>
# <p>HERE TPEG API</p>
# </li>
# <li>
# <p>HERE Traffic Vector Tile API</p>
# </li>
# <li>
# <p>HERE Traffic Raster Tile API</p>
# </li>
# <li>
# <p>HERE Probe Data</p>
# </li>
# <li>Fleet Optimization Package</li>
# </ul>
# </li>
# <li>
# <p>Asset Tracking</p>
# <ul>
# <li>HERE Tracking API</li>
# <li>Development enablers</li>
# </ul>
# </li>
# <li>
# <p>HERE SDK</p>
# <ul>
# <li>
# <p>Explore Edition</p>
# </li>
# <li>
# <p>Navigate Edition</p>
# </li>
# <li>
# <p>Lite Edition</p>
# </li>
# <li>
# <p>Premium Edition</p>
# </li>
# <li>
# <p>Starter Edition</p>
# </li>
# <li>HERE Live Sense SDK</li>
# </ul>
# </li>
# <li>
# <p>HERE Anonymizer Self-Hosted</p>
# </li>
# <li>
# <p>Platform management</p>
# </li>
# <li>
# <p>Identity and Access Management</p>
# </li>
# <li>
# <p>Cost Management</p>
# </li>
# <li>
# <p>HERE Workspace</p>
# <ul>
# <li>
# <p>HERE Style Editor</p>
# </li>
# <li>
# <p>Pipelines API</p>
# </li>
# <li>
# <p>HERE Data SDK</p>
# </li>
# <li>
# <p>HERE Data SDK for Java and Scala</p>
# </li>
# <li>
# <p>Data Client Library</p>
# </li>
# <li>
# <p>Data Client Base Library</p>
# </li>
# <li>
# <p>Data Processing Library</p>
# </li>
# <li>
# <p>Location Library</p>
# </li>
# <li>
# <p>Data Archiving Library</p>
# </li>
# <li>
# <p>Index Compaction Library</p>
# </li>
# <li>
# <p>Data API</p>
# </li>
# <li>
# <p>Data API</p>
# </li>
# <li>
# <p>API Lookup</p>
# </li>
# <li>Data Inspector Library</li>
# </ul>
# </li>
# <li>
# <p>HERE Marketplace</p>
# </li>
# <li>
# <p>Command Line Interface</p>
# </li>
# <li>
# <p>Monitoring and Logging</p>
# </li>
# <li>
# <p>System Status API</p>
# </li>
# <li>
# <p>HERE Deeplinking API</p>
# </li>
# <li>
# <p>Sensor Data Ingestion Interface SDII</p>
# </li>
# <li>
# <p>SENSORIS</p>
# </li>
# </ul>
# <h5>Technology</h5>
# <ul>
# <li>
# <p>Android</p>
# </li>
# <li>
# <p>Async</p>
# </li>
# <li>
# <p>C++</p>
# </li>
# <li>
# <p>Flutter</p>
# </li>
# <li>
# <p>iOS</p>
# </li>
# <li>
# <p>Java</p>
# </li>
# <li>
# <p>JavaScript</p>
# </li>
# <li>
# <p>Linux</p>
# </li>
# <li>
# <p>Python</p>
# </li>
# <li>
# <p>REST API</p>
# </li>
# <li>
# <p>Scala</p>
# </li>
# <li>
# <p>TypeScript</p>
# </li>
# </ul>
# <h5>Doc type</h5>
# <ul>
# <li>
# <p>API reference</p>
# </li>
# <li>
# <p>Changelog</p>
# </li>
# <li>
# <p>Coverage information</p>
# </li>
# <li>
# <p>Data specification</p>
# </li>
# <li>
# <p>Developer guide</p>
# </li>
# <li>
# <p>Examples</p>
# </li>
# <li>
# <p>Migration guide</p>
# </li>
# <li>
# <p>Policies</p>
# </li>
# <li>
# <p>Product Lifecycle Policy</p>
# </li>
# <li>
# <p>Service Level Agreement</p>
# </li>
# <li>
# <p>Incident Management</p>
# </li>
# <li>
# <p>Workspace and Marketplace Limits and Quotas</p>
# </li>
# <li>
# <p>Local Maps Regulatory Approval</p>
# </li>
# <li>
# <p>Release notes</p>
# </li>
# <li>
# <p>Tutorial</p>
# </li>
# <li>
# <p>User Guide</p>
# </li>
# </ul>
# <h5>Version</h5>
# <ul>
# <li>
# <p>v1</p>
# </li>
# <li>
# <p>v2</p>
# </li>
# <li>
# <p>v3</p>
# </li>
# <li>
# <p>v6</p>
# </li>
# <li>
# <p>v7</p>
# </li>
# <li>
# <p>v8</p>
# </li>
# </ul>
# <h5>Product lifecycle</h5>
# <ul>
# <li>
# <p>Beta</p>
# </li>
# <li>
# <p>Deprecated</p>
# </li>
# <li>
# <p>In maintenance</p>
# </li>
# </ul>
# <p>SaveCloseClear All Filters</p>
# <p>This publication</p>
# <h1>HERE Maps API for JavaScript - Developer Guide: Get started with Japan data</h1>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/geo-shapes.html">Previous: Geo shapes</a></p>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/get-started-bundling.html">Next: Bundle HERE Maps API for JavaScript</a></p>
# <p>Share</p>
# <p>Share to emailCopy article URL</p>
# <p>Feedback</p>
# <p>Print</p>
# <p>Expand</p>
# <p>Collapse</p>
# <ul>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/README.html">Introduction</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/quick-start.html">Get started</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/browser-support.html">Browser support</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/modules.html">Modules</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/api-versions.html">API Versions</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/migration.html">Migrate to the Maps API for JavaScript 3.1</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/harp-migrate.html">Migrate to the HARP engine</a></p>
# </li>
# <li>
# <p>Concepts</p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/map-types.html">Map types</a></p>
# <ul>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/vector.html">Vector map types</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/structure-overview.html">Scene structure overview</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/default-styles.html">Default styles</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/custom-styles.html">Custom styles</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/filters.html">Filters</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/sources.html">Sources</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/styles.html">Practical examples</a></p>
# </li>
# <li><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/raster.html">Raster map types</a></li>
# <li><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/map-events.html">Map events</a></li>
# </ul>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/map-objects.html">Map objects</a></p>
# <ul>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/marker-objects.html">Marker objects</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/overlays.html">Overlays</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/geo-shapes.html">Geo shapes</a></p>
# </li>
# <li>Tutorials</li>
# </ul>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/get-started-japan.html">Get started with Japan data</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/get-started-bundling.html">Bundle HERE Maps API for JavaScript</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/map-controls-ui.html">Modify your map using map controls and UI</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/raster-example.html">Render maps by using raster tiles</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/geocoding.html">Resolve and code addresses using geocoding</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/routing.html">Calculate routes</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/draggable-directions.html">Enable draggable directions</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/geopolitical-views.html">Apply geopolitical views</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/traffic.html">Retrieve and display traffic data</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/clustering.html">Cluster map data sets</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/fleet-telematics-advanced-data-sets.html">Show Fleet Telematics Advanced Data Sets layer on the map</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/fleet-telematics-custom-locations.html">Show Fleet Telematics Custom Locations layer on the map</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/kml-support.html">Create content using KML support</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/display-iml.html">Display Interactive Map Layers on a map</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/indoor-maps.html">Integrate HERE Indoor Map</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/react-practices.html">Working with React</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/angular-practices.html">Working with Angular</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/typescript.html">Get started with TypeScript</a></p>
# </li>
# <li>
# <p><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/custom-configurations.html">Setting domain name and service path</a></p>
# </li>
# <li><a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/best-practices.html">Best practices</a></li>
# </ul>
# <p><a href="/docs/">Home</a><a href="/docs/bundle/maps-api-for-javascript-developer-guide">HERE Maps API for JavaScript - Developer Guide</a>Get started with Japan dataCurrent page</p>
# <p>Table of Contents</p>
# <h1>Get started with Japan data</h1>
# <p>This section shows how to start using the HERE Maps API for JavaScript with the Japan specific data and map style.</p>
# <p>To access this data, register for a HERE account. For more information, see <a href="https://www.here.com/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/quick-start.html#get-a-here-account">Get a HERE account</a>.</p>
# <h2>Use case</h2>
# <p>Sections below follow the steps of the <a href="/docs/bundle/maps-api-for-javascript-developer-guide/page/topics/quick-start.html">Quick Start</a> chapter but additionally describe how to:</p>
# <ol>
# <li>Configure the JavaScript API to call the <code>"core"</code> layer of the <a href="https://developer.here.com/documentation/vector-tiles-api/dev_guide/index.html">Vector Tile API</a></li>
# <li>Fetch the map style that works best with the Japan data.</li>
# <li>Display a route within Japan.</li>
# </ol>
# <h2>Load the API Code Libraries</h2>
# <p>There are no changes in how the JavaScript API is included on the page, here is the complete <code>&lt;head&gt;</code> element that loads the core and service modules and ensures optimum performance on mobile devices.</p>
# <p>Explain this code</p>
# <pre><code class="language-xml">&lt;!DOCTYPE html&gt;
#   &lt;html&gt;
#     &lt;head&gt;
#       ...
#       &lt;meta name="viewport" content="initial-scale=1.0,
#         width=device-width" /&gt;
#       &lt;script src="https://js.api.here.com/v3/3.1/mapsjs-core.js"
#         type="text/javascript" charset="utf-8"&gt;&lt;/script&gt;
#       &lt;script src="https://js.api.here.com/v3/3.1/mapsjs-service.js"
#         type="text/javascript" charset="utf-8"&gt;&lt;/script&gt;
#       ...
#     &lt;/head&gt;
#     &lt;body&gt;
#       &lt;div style="width: 640px; height: 480px" id="mapContainer"&gt;&lt;/div&gt;
#
# </code></pre>
# <p>Copy</p>
# <h2>Initialize Communication with Back-End Services</h2>
# <p>Initialize the <code>Platform</code> object normally by passing it the API Key:</p>
# <p>Explain this code</p>
# <pre><code class="language-javascript">var platform = new H.service.Platform({
#   'apikey': '{YOUR_API_KEY}'
# });
#
# </code></pre>
# <p>Copy</p>
# <h2>Initialize the map</h2>
# <ol>
# <li>Create an instance of the Vector Tile Service object that is pre-configured to use the <a href="https://www.here.com/docs/bundle/vector-tile-api-developer-guide/page/topics/map-parameter.html"><code>core</code> endpoint</a> that provides the Japan data.</li>
# <li>Create a layer that uses the map style optimised for the display of the Japan data. The style can be adjusted with the help of <a href="https://enterprise.here.com/map-style-editor/">Map Customization Tool</a>.</li>
# <li>
# <p>Instantiate an <code>H.Map</code> object, specifying:</p>
# </li>
# <li>
# <p>the map container element</p>
# </li>
# <li>the layer created in the previous step</li>
# <li>the zoom level at which to display the map</li>
# <li>the geographic coordinates of the point on which to center the map</li>
# </ol>
# <p>Explain this code</p>
# <pre><code class="language-javascript">
# // configure an OMV service to use the `core` enpoint
# var omvService = platform.getOMVService({path:  'v2/vectortiles/core/mc'});
# var baseUrl = 'https://js.api.here.com/v3/3.1/styles/omv/oslo/japan/';
#
# // create a Japan specific style
# var style = new H.map.Style(`${baseUrl}normal.day.yaml`, baseUrl);
#
# // instantiate provider and layer for the basemap
# var omvProvider = new H.service.omv.Provider(omvService, style);
# var omvlayer = new H.map.layer.TileLayer(omvProvider, {max: 22});
#
# // instantiate (and display) a map:
# var map = new H.Map(
#     document.getElementById('mapContainer'),
#     omvlayer,
#     {
#       zoom: 17,
#       center: {lat: 35.68026, lng: 139.76744}
#     });
# </code></pre>
# <p>Copy</p>
# <p>The implementation displays the following map image:</p>
# <p><img alt="A basic non-interactive map" src="https://docs-be.here.com/bundle/maps-api-for-javascript-developer-guide/page/topics/../graphics/map-basic-japan.png?_LANG=enus"/>A basic non-interactive map</p>
# <h2>Geocoding and Routing</h2>
# <p>In order to use the <a href="https://developer.here.com/documentation/geocoding-search-api/dev_guide/topics/japan.html">Geocoding and Search</a> and <a href="https://developer.here.com/documentation/routing-api/dev_guide/index.html">Routing API v8</a> with the Japan data no further adjustments needed.</p>
# <p>The following example demonstrates how to geocode two points in the Tokyo area and calculate the route between them. The snippet below:</p>
# <ul>
# <li>geocodes start and finish point of the route.</li>
# <li>defines the routing parameters and the routing callback that parses the response and displays the route polyline.</li>
# <li>instantiates the routing service and calculates the route</li>
# </ul>
# <p>Explain this code</p>
# <pre><code class="language-javascript">let origin;
# let destination;
#
# let onError = (error) =&gt; {
#   alert(error.message);
# }
#
# // create an instance of the routing service and make a request
# let router = platform.getRoutingService(null, 8);
#
# // Define a callback function to process the routing response:
# let onResult = function(result) {
#   // ensure that at least one route was found
#   if (result.routes.length) {
#     result.routes[0].sections.forEach((section) =&gt; {
#          // Create a linestring to use as a point source for the route line
#         let linestring = H.geo.LineString.fromFlexiblePolyline(section.polyline);
#
#         // Create a polyline to display the route:
#         let routeLine = new H.map.Polyline(linestring, {
#           style: { strokeColor: 'blue', lineWidth: 3 }
#         });
#
#         // Create a marker for the start point:
#         let startMarker = new H.map.Marker(section.departure.place.location);
#
#         // Create a marker for the end point:
#         let endMarker = new H.map.Marker(section.arrival.place.location);
#
#         // Add the route polyline and the two markers to the map:
#         map.addObjects([routeLine, startMarker, endMarker]);
#
#         // Set the map's viewport to make the whole route visible:
#         map.getViewModel().setLookAtData({bounds: routeLine.getBoundingBox()});
#     });
#   }
# };
#
# let routingParameters = {
#   'transportMode': 'car',
#   // Include the route shape in the response
#   'return': 'polyline'
# };
#
# // Define a callback that calculates the route
# let calculateRoute = () =&gt; {
#   // Make sure that both destination and origin are present
#   if (!origin || !destination) return;
#
#   // Add origin and destination to the routing parameters
#   routingParameters.origin = origin;
#   routingParameters.destination = destination;
#
#   router.calculateRoute(routingParameters, onResult, onError);
# }
#
# // get the instance of the Search service
# var service = platform.getSearchService();
#
# // geocode origin point
# service.geocode({
#   q: '東京都中央区佃１‐１１‐８'
# }, (result) =&gt; {
#   origin = result.items[0].position.lat + ',' + result.items[0].position.lng;
#   calculateRoute();
# }, onError);
#
# // geocode a destination point
# service.geocode({
#   q: '東京都千代田区丸の内１‐９'
# }, (result) =&gt; {
#   destination = result.items[0].position.lat + ',' + result.items[0].position.lng;
#   calculateRoute();
# }, onError)
#
# </code></pre>
# <p>Copy</p>
# <p>The picture below demonstrates the result of the routing request from the code above.</p>
# <p><img alt="Map with the Route" src="https://docs-be.here.com/bundle/maps-api-for-javascript-developer-guide/page/topics/../graphics/map-routing-japan.png?_LANG=enus"/>Map with the Route</p>
# <h5>In This Article</h5>
# <ul>
# <li><a href="#use-case">Use case</a></li>
# <li><a href="#load-the-api-code-libraries">Load the API Code Libraries</a></li>
# <li><a href="#initialize-communication-with-backend-services">Initialize Communication with Back-End Services</a></li>
# <li><a href="#initialize-the-map">Initialize the map</a></li>
# <li><a href="#geocoding-and-routing">Geocoding and Routing</a></li>
# </ul>
# <h5>Related Publications</h5>
# <ul>
# <li><a href="https://www.here.com/docs/bundle/maps-api-for-javascript-release-notes/page/README.html">Release notes</a></li>
# <li><a href="https://www.here.com/docs/bundle/maps-api-for-javascript-api-reference/page/index.html">API reference</a></li>
# </ul>
# <p>Was this article helpful?</p>
# <p>LikeDislike</p>
# <h2>You can help improve the docs</h2>
# <h2>Rate our docs!</h2>
# <p>Rating a page is easy - just click the Like or Dislike button at the bottom of documentation pages. We look at page ratings to identify what's working and where we need to improve. We read all comments!</p>
# <p>TitleResults for “How to create a CRG?”Also Available inAlert</p>
# <h4>Provide feedback for this article</h4>
# <p>Was this article helpful?</p>
# <p>LikeDislike</p>
# <p>Comments</p>
# <p>Your email</p>
# <p><strong>Reminder</strong> You can stay anonymous, but entering your email address will help us to get back to you.</p>
# <p><a href="/docs/auth/login">Login</a>Dismiss</p>
# <p>Send FeedbackCancel</p>
# <h4>Provide feedback for this article</h4>
# <p>Was this article helpful?</p>
# <p>LikeDislike</p>
# <p>Comments</p>
# <p>Your email</p>
# <p><strong>Reminder</strong> You can stay anonymous, but entering your email address will help us to get back to you.</p>
# <p><a href="/docs/auth/login">Login</a>Dismiss</p>
# <p>Send FeedbackCancel</p>
# <h4>Provide feedback for this article</h4>
# <p>Was this article helpful?</p>
# <p>LikeDislike</p>
# <p>Comments</p>
# <p>Your email</p>
# <p><strong>Reminder</strong> You can stay anonymous, but entering your email address will help us to get back to you.</p>
# <p><a href="/docs/auth/login">Login</a>Dismiss</p>
# <p>Send FeedbackCancel</p>
# <h4>Explain this code</h4>
# <p>Show code</p>
# <pre><code class="language-xml">&lt;!DOCTYPE html&gt;
#   &lt;html&gt;
#     &lt;head&gt;
#       ...
#       &lt;meta name="viewport" content="initial-scale=1.0,
#         width=device-width" /&gt;
#       &lt;script src="https://js.api.here.com/v3/3.1/mapsjs-core.js"
#         type="text/javascript" charset="utf-8"&gt;&lt;/script&gt;
#       &lt;script src="https://js.api.here.com/v3/3.1/mapsjs-service.js"
#         type="text/javascript" charset="utf-8"&gt;&lt;/script&gt;
#       ...
#     &lt;/head&gt;
#     &lt;body&gt;
#       &lt;div style="width: 640px; height: 480px" id="mapContainer"&gt;&lt;/div&gt;
#
# </code></pre>
# <p>Copy</p>
# <p>How was this response?</p>
# <p>Code explanation using AI</p>
# <h4>Explain this code</h4>
# <p>Show code</p>
# <pre><code class="language-javascript">var platform = new H.service.Platform({
#   'apikey': '{YOUR_API_KEY}'
# });
#
# </code></pre>
# <p>Copy</p>
# <p>How was this response?</p>
# <p>Code explanation using AI</p>
# <h4>Explain this code</h4>
# <p>Show code</p>
# <pre><code class="language-javascript">
# // configure an OMV service to use the `core` enpoint
# var omvService = platform.getOMVService({path:  'v2/vectortiles/core/mc'});
# var baseUrl = 'https://js.api.here.com/v3/3.1/styles/omv/oslo/japan/';
#
# // create a Japan specific style
# var style = new H.map.Style(`${baseUrl}normal.day.yaml`, baseUrl);
#
# // instantiate provider and layer for the basemap
# var omvProvider = new H.service.omv.Provider(omvService, style);
# var omvlayer = new H.map.layer.TileLayer(omvProvider, {max: 22});
#
# // instantiate (and display) a map:
# var map = new H.Map(
#     document.getElementById('mapContainer'),
#     omvlayer,
#     {
#       zoom: 17,
#       center: {lat: 35.68026, lng: 139.76744}
#     });
# </code></pre>
# <p>Copy</p>
# <p>How was this response?</p>
# <p>Code explanation using AI</p>
# <h4>Explain this code</h4>
# <p>Show code</p>
# <pre><code class="language-javascript">let origin;
# let destination;
#
# let onError = (error) =&gt; {
#   alert(error.message);
# }
#
# // create an instance of the routing service and make a request
# let router = platform.getRoutingService(null, 8);
#
# // Define a callback function to process the routing response:
# let onResult = function(result) {
#   // ensure that at least one route was found
#   if (result.routes.length) {
#     result.routes[0].sections.forEach((section) =&gt; {
#          // Create a linestring to use as a point source for the route line
#         let linestring = H.geo.LineString.fromFlexiblePolyline(section.polyline);
#
#         // Create a polyline to display the route:
#         let routeLine = new H.map.Polyline(linestring, {
#           style: { strokeColor: 'blue', lineWidth: 3 }
#         });
#
#         // Create a marker for the start point:
#         let startMarker = new H.map.Marker(section.departure.place.location);
#
#         // Create a marker for the end point:
#         let endMarker = new H.map.Marker(section.arrival.place.location);
#
#         // Add the route polyline and the two markers to the map:
#         map.addObjects([routeLine, startMarker, endMarker]);
#
#         // Set the map's viewport to make the whole route visible:
#         map.getViewModel().setLookAtData({bounds: routeLine.getBoundingBox()});
#     });
#   }
# };
#
# let routingParameters = {
#   'transportMode': 'car',
#   // Include the route shape in the response
#   'return': 'polyline'
# };
#
# // Define a callback that calculates the route
# let calculateRoute = () =&gt; {
#   // Make sure that both destination and origin are present
#   if (!origin || !destination) return;
#
#   // Add origin and destination to the routing parameters
#   routingParameters.origin = origin;
#   routingParameters.destination = destination;
#
#   router.calculateRoute(routingParameters, onResult, onError);
# }
#
# // get the instance of the Search service
# var service = platform.getSearchService();
#
# // geocode origin point
# service.geocode({
#   q: '東京都中央区佃１‐１１‐８'
# }, (result) =&gt; {
#   origin = result.items[0].position.lat + ',' + result.items[0].position.lng;
#   calculateRoute();
# }, onError);
#
# // geocode a destination point
# service.geocode({
#   q: '東京都千代田区丸の内１‐９'
# }, (result) =&gt; {
#   destination = result.items[0].position.lat + ',' + result.items[0].position.lng;
#   calculateRoute();
# }, onError)
#
# </code></pre>
# <p>Copy</p>
# <p>How was this response?</p>
# <p>Code explanation using AI</p>
# <h4>Feedback</h4>
# <p>Provide additional feedback</p>
# <p>Send feedbackCancel</p>
# <h4>Feedback</h4>
# <p>Provide additional feedback</p>
# <p>Send feedbackCancel</p>
# <h4>Feedback</h4>
# <p>Provide additional feedback</p>
# <p>Send feedbackCancel</p>
# <h4>Feedback</h4>
# <p>Provide additional feedback</p>
# <p>Send feedbackCancel</p>

# %%
def extract_list_content(list_element):
    list_content = []
    for item in list_element.find_all('li'):
        # Find any code blocks inside the list item
        if item.find('pre'):
            list_content.append({'type': 'code', 'content': item.get_text()})
        else:
            # Otherwise, it's just text
            if item.get_text() not in ['Explain this code', 'Copy']:
                list_content.append({'type': 'text', 'content': item.get_text()})

    return list_content

# %%
soup = BeautifulSoup(html_content, 'html.parser')
    
# Find all h2 headings
h2_headings = soup.find_all('h2')

extracted_data = []

# Loop through all sections
for section in h2_headings[:-1]:
    section_title = section.get_text().strip()  # Get the section title
    section_content = []  # Store content for each section
    
    # Find the next sibling (the content after h2)
    sibling = section.find_next_sibling()
    while sibling and sibling.name != 'h2':
        # Extract text and code content
        if sibling.name == 'p' or sibling.name == 'code':  # This is text
            if sibling.get_text() not in ['Explain this code', 'Copy']:
                section_content.append({'type': 'text', 'content': sibling.get_text()})
        elif sibling.name == 'pre':  # This is code
            section_content.append({'type': 'code', 'content': sibling.get_text()})
        elif sibling.name == 'ul' or sibling.name == 'ol':  # This is an unordered/ordered list
            # Extract both text and code inside the list
            list_items = extract_list_content(sibling)
            section_content.extend(list_items)

        sibling = sibling.find_next_sibling()

    extracted_data.append({
        'section_title': section_title,
        'content': section_content
    })

# %%
extracted_data[5]
# Out:
# {'section_title': 'Initialize the map',
#  'content': [{'type': 'text',
#    'content': 'Create an instance of the Vector Tile Service object that is pre-configured to use the core endpoint that provides the Japan data.'},
#   {'type': 'text',
#    'content': 'Create a layer that uses the map style optimised for the display of the Japan data. The style can be adjusted with the help of Map Customization Tool.'},
#   {'type': 'text', 'content': '\nInstantiate an H.Map object, specifying:\n'},
#   {'type': 'text', 'content': '\nthe map container element\n'},
#   {'type': 'text', 'content': 'the layer created in the previous step'},
#   {'type': 'text', 'content': 'the zoom level at which to display the map'},
#   {'type': 'text',
#    'content': 'the geographic coordinates of the point on which to center the map'},
#   {'type': 'code',
#    'content': "\n// configure an OMV service to use the `core` enpoint\nvar omvService = platform.getOMVService({path:  'v2/vectortiles/core/mc'});\nvar baseUrl = 'https://js.api.here.com/v3/3.1/styles/omv/oslo/japan/';\n\n// create a Japan specific style\nvar style = new H.map.Style(`${baseUrl}normal.day.yaml`, baseUrl);\n\n// instantiate provider and layer for the basemap\nvar omvProvider = new H.service.omv.Provider(omvService, style);\nvar omvlayer = new H.map.layer.TileLayer(omvProvider, {max: 22});\n\n// instantiate (and display) a map:\nvar map = new H.Map(\n    document.getElementById('mapContainer'),\n    omvlayer,\n    {\n      zoom: 17,\n      center: {lat: 35.68026, lng: 139.76744}\n    });\n"},
#   {'type': 'text',
#    'content': 'The implementation displays the following map image:'},
#   {'type': 'text', 'content': 'A basic non-interactive map'}]}

# %%
def create_text_to_code_mapping(extracted_data):
    mappings = []

    for section in extracted_data:
        section_title = section['section_title']
        text_content = ""
        code_content = ""

        # Separate text and code content
        for item in section['content']:
            if item['type'] == 'text':
                text_content += item['content'] + "\n"
            elif item['type'] == 'code':
                code_content += item['content'] + "\n"
        
        # Create a mapping between the text and the corresponding code
        if text_content and code_content:
            mappings.append({
                'section_title': section_title,
                'text': text_content.strip(),
                'code': code_content.strip()
            })
    
    return mappings

# %%
mappings = create_text_to_code_mapping(extracted_data)

# %%
mappings
# Out:
# [{'section_title': 'Load the API Code Libraries',
#   'text': 'There are no changes in how the JavaScript API is included on the page, here is the complete <head> element that loads the core and service modules and ensures optimum performance on mobile devices.',
#   'code': '<!DOCTYPE html>\n  <html>\n    <head>\n      ...\n      <meta name="viewport" content="initial-scale=1.0,\n        width=device-width" />\n      <script src="https://js.api.here.com/v3/3.1/mapsjs-core.js"\n        type="text/javascript" charset="utf-8"></script>\n      <script src="https://js.api.here.com/v3/3.1/mapsjs-service.js"\n        type="text/javascript" charset="utf-8"></script>\n      ...\n    </head>\n    <body>\n      <div style="width: 640px; height: 480px" id="mapContainer"></div>'},
#  {'section_title': 'Initialize Communication with Back-End Services',
#   'text': 'Initialize the Platform object normally by passing it the API Key:',
#   'code': "var platform = new H.service.Platform({\n  'apikey': '{YOUR_API_KEY}'\n});"},
#  {'section_title': 'Initialize the map',
#   'text': 'Create an instance of the Vector Tile Service object that is pre-configured to use the core endpoint that provides the Japan data.\nCreate a layer that uses the map style optimised for the display of the Japan data. The style can be adjusted with the help of Map Customization Tool.\n\nInstantiate an H.Map object, specifying:\n\n\nthe map container element\n\nthe layer created in the previous step\nthe zoom level at which to display the map\nthe geographic coordinates of the point on which to center the map\nThe implementation displays the following map image:\nA basic non-interactive map',
#   'code': "// configure an OMV service to use the `core` enpoint\nvar omvService = platform.getOMVService({path:  'v2/vectortiles/core/mc'});\nvar baseUrl = 'https://js.api.here.com/v3/3.1/styles/omv/oslo/japan/';\n\n// create a Japan specific style\nvar style = new H.map.Style(`${baseUrl}normal.day.yaml`, baseUrl);\n\n// instantiate provider and layer for the basemap\nvar omvProvider = new H.service.omv.Provider(omvService, style);\nvar omvlayer = new H.map.layer.TileLayer(omvProvider, {max: 22});\n\n// instantiate (and display) a map:\nvar map = new H.Map(\n    document.getElementById('mapContainer'),\n    omvlayer,\n    {\n      zoom: 17,\n      center: {lat: 35.68026, lng: 139.76744}\n    });"},
#  {'section_title': 'Geocoding and Routing',
#   'text': 'In order to use the Geocoding and Search and Routing API v8 with the Japan data no further adjustments needed.\nThe following example demonstrates how to geocode two points in the Tokyo area and calculate the route between them. The snippet below:\ngeocodes start and finish point of the route.\ndefines the routing parameters and the routing callback that parses the response and displays the route polyline.\ninstantiates the routing service and calculates the route\nThe picture below demonstrates the result of the routing request from the code above.\nMap with the Route\nUse case\nLoad the API Code Libraries\nInitialize Communication with Back-End Services\nInitialize the map\nGeocoding and Routing\nRelease notes\nAPI reference\nWas this article helpful?\nLikeDislike',
#   'code': "let origin;\nlet destination;\n\nlet onError = (error) => {\n  alert(error.message);\n}\n\n// create an instance of the routing service and make a request\nlet router = platform.getRoutingService(null, 8);\n\n// Define a callback function to process the routing response:\nlet onResult = function(result) {\n  // ensure that at least one route was found\n  if (result.routes.length) {\n    result.routes[0].sections.forEach((section) => {\n         // Create a linestring to use as a point source for the route line\n        let linestring = H.geo.LineString.fromFlexiblePolyline(section.polyline);\n\n        // Create a polyline to display the route:\n        let routeLine = new H.map.Polyline(linestring, {\n          style: { strokeColor: 'blue', lineWidth: 3 }\n        });\n\n        // Create a marker for the start point:\n        let startMarker = new H.map.Marker(section.departure.place.location);\n\n        // Create a marker for the end point:\n        let endMarker = new H.map.Marker(section.arrival.place.location);\n\n        // Add the route polyline and the two markers to the map:\n        map.addObjects([routeLine, startMarker, endMarker]);\n\n        // Set the map's viewport to make the whole route visible:\n        map.getViewModel().setLookAtData({bounds: routeLine.getBoundingBox()});\n    });\n  }\n};\n\nlet routingParameters = {\n  'transportMode': 'car',\n  // Include the route shape in the response\n  'return': 'polyline'\n};\n\n// Define a callback that calculates the route\nlet calculateRoute = () => {\n  // Make sure that both destination and origin are present\n  if (!origin || !destination) return;\n\n  // Add origin and destination to the routing parameters\n  routingParameters.origin = origin;\n  routingParameters.destination = destination;\n\n  router.calculateRoute(routingParameters, onResult, onError);\n}\n\n// get the instance of the Search service\nvar service = platform.getSearchService();\n\n// geocode origin point\nservice.geocode({\n  q: '東京都中央区佃１‐１１‐８'\n}, (result) => {\n  origin = result.items[0].position.lat + ',' + result.items[0].position.lng;\n  calculateRoute();\n}, onError);\n\n// geocode a destination point\nservice.geocode({\n  q: '東京都千代田区丸の内１‐９'\n}, (result) => {\n  destination = result.items[0].position.lat + ',' + result.items[0].position.lng;\n  calculateRoute();\n}, onError)"}]
